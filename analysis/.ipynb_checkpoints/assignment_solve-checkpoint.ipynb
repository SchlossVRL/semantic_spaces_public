# %% [markdown]
# # Assignment problem solver
# #### Laurent Lessard

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import scipy
from scipy.optimize import linear_sum_assignment
import seaborn as sns
from matplotlib import pyplot as plt
import math
import warnings
warnings.filterwarnings('ignore')

# %%
"""
Input is a m x n array of (concepts) x (colors) filled with association ratings
Output is a list of length m with the index of the color that should be associated with each concept
"""
def assignment_solve( ratings, method="balanced" ):
    m,n = ratings.shape
    assert m <= n, "More concepts than colors, assignment impossible!"
    
    # isolated merit function (only considers target in isolation)
    if method == "isolated":
        merit_matrix = ratings
    
    # balanced merit function (balances ratings of target vs off-target objects with each color)
    elif method == "balanced":
        t = 1  # this is the penalty parameter. t=1 for balanced, t=0 recovers isolated case.
        merit_matrix = np.zeros((m,n))
        for i in range(m):
            for j in range(n):
                merit_matrix[i,j] = ratings[i,j] - t*ratings[np.arange(m)!=i,j].max()
    
    # baseline merit function (uniformly bad assignment)
    elif method == "baseline":
        merit_matrix = np.zeros((m,n))
        for i in range(m):
            for j in range(n):
                merit_matrix[i,j] = -abs( ratings[i,j] - ratings[np.arange(m)!=i,j].max() )
                
    else:
        assert False, "unknown method in assignment problem"
        
    row_ind, col_ind = linear_sum_assignment( merit_matrix, maximize=True )
    return col_ind

# %% [markdown]
# ## Examples

# %%
# 3 object and 5 colors
A = np.array( [[ 1, 4, 6, 2, 5 ],
               [ 2, 1, 4, 5, 7 ],
               [ 4, 2, 9, 2, 1 ]] )

# %%
"""
ISOLATED METHOD:
The max for each row is (6,7,9) but this can't work because the first row's 6
conflicts with the third row's 9. The best option is to pick 4 from the first
row, so the optimal sum is 4+7+9.
"""
print( assignment_solve(A, method="isolated") )
# Out:
# [1 4 2]

# %%
"""
BALANCED METHOD:
This method compares each number to the largest other number in its column and
tries to maximize this difference. The assignment 4+7+9 is problematic because
the 7 is only 2 away from the 5 above it. By picking 5 instead for the second
row, we increase this distance to 3. So the assignment is less confusable.
"""
print( assignment_solve(A, method="balanced") )
# Out:
# [1 3 2]

# %%
"""
BASELINE METHOD:
This method maximizes confusability. By picking (4,7,4) from first,second,third
rows, we get items that are all exactly +2 larger than the other choices in their
respective columns. So all items are equally likely to be mis-assigned.
"""
print( assignment_solve(A, method="baseline") )
# Out:
# [4 0 1]

# %%
print(scipy.__version__)
# Out:
# 1.4.1

# %%
p = pd.read_csv('../data/ratings_matrix.csv')

### read in datafiles

#d = pd.read_csv('../data/uw_71_ratings_matrix.csv')

#d = pd.read_csv('../data/colorabilty_ratings_matrix.csv')

#d = d.rename(columns={"Unnamed: 0": "concept"})
p = p.rename(columns={"Unnamed: 0": "concept"})

# %%
d=p

# %%
## Get only ratings columns
ratings_cols = d.columns[1:]
ratings_arr = np.array(d[ratings_cols])


## compute p_ij
ratings_arr = ratings_arr/ratings_arr.sum(axis=0)

## compute -p_ij*logp
def compute_ent(array):
    logs= []
    for i,a in enumerate(array):
        if array[i]==0:
            logs.append(0)
        else:
            logs.append(math.log(array[i]))
    out = -array*np.array(logs)
    return out

ent_arr = np.apply_along_axis(compute_ent, 1, ratings_arr)

## compute entropy per color
H_n = ent_arr.sum(axis=0)

## get worst and best colors

worst_color_inds = (-H_n).argsort()[:20]+1
best_color_inds = (H_n).argsort()[:20]+1

# %% [markdown]
# ## Solve Assignment inference

# %%
d
# Out:
#        concept        V1        V2        V3        V4        V5        V6  \
# 0        dress  0.418043  0.591979  0.547436  0.527781  0.505377  0.516967
# 1        pants  0.303036  0.796007  0.527568  0.446216  0.211604  0.186726
# 2        shirt  0.378499  0.632613  0.505528  0.711150  0.383646  0.369988
# 3        shoes  0.264595  0.527570  0.385453  0.350714  0.207400  0.193543
# 4        socks  0.237471  0.311504  0.395419  0.471614  0.283157  0.209067
# 5        above  1.000000  0.596509  0.836466  0.767670  0.514774  0.519614
# 6        below  0.165639  0.505583  0.471365  0.330767  0.833050  0.364712
# 7       beside  0.852296  0.507106  0.865896  0.864897  0.439354  0.727600
# 8          far  0.094911  0.993457  0.676011  0.562246  0.896669  0.730949
# 9         near  0.909897  0.504866  0.592704  0.379895  0.362574  0.428630
# 10       angry  0.128760  0.579581  0.387157  0.136131  0.704026  0.401377
# 11     disgust  0.368422  0.685643  0.463797  0.185537  0.528497  0.397386
# 12     fearful  0.118852  0.391015  0.235907  0.227780  0.351667  0.498526
# 13       happy  0.811480  0.425562  0.554218  0.741827  0.444304  0.711670
# 14         sad  0.000000  1.000000  0.674213  0.328542  0.957595  0.373210
# 15   blueberry  0.584771  0.884971  0.753330  0.482320  0.710087  0.421957
# 16       lemon  0.201342  0.115311  0.200172  0.145457  0.000000  0.204017
# 17       mango  0.091972  0.132788  0.174677  0.128674  0.196963  0.150626
# 18  strawberry  0.170454  0.191710  0.086186  0.160990  0.202328  0.179728
# 19  watermelon  0.195639  0.083056  0.200028  0.037650  0.112298  0.131339
# 20       beach  0.966806  0.758901  0.946247  0.921592  0.142753  0.176777
# 21       field  0.164448  0.163246  0.189233  0.277985  0.032719  0.102382
# 22       ocean  0.726147  0.758981  1.000000  0.773081  0.168977  0.155476
# 23         sky  0.905283  0.757436  0.967001  1.000000  0.181483  0.260722
# 24      sunset  0.264458  0.462415  0.337159  0.443478  0.241055  0.386528
# 25        dawn  0.676002  0.466898  0.505038  0.900976  0.170056  0.572654
# 26         day  0.892308  0.339987  0.513286  1.000000  0.190417  0.312868
# 27        dusk  0.295940  1.000000  0.721609  0.275003  0.988202  0.859233
# 28       night  0.173054  0.659866  0.434744  0.273412  0.507163  0.399768
# 29        noon  0.984066  0.392039  0.457856  1.000000  0.206615  0.251259
#
#           V7        V8        V9  ...       V49       V50       V51       V52  \
# 0   0.514554  0.596459  0.626389  ...  0.035334  0.469479  0.157505  0.204209
# 1   0.277446  0.247865  0.194837  ...  0.176888  0.348800  0.193411  0.248162
# 2   0.490393  0.212205  0.496699  ...  0.009620  0.388710  0.144586  0.169797
# 3   0.127081  0.179807  0.082750  ...  0.170230  0.204951  0.143955  0.180763
# 4   0.315668  0.144671  0.187786  ...  0.211128  0.189744  0.266413  0.105445
# 5   0.610559  0.602333  0.791370  ...  0.481270  0.864706  0.553624  0.809696
# 6   0.375855  0.736281  0.431176  ...  0.584292  0.424251  0.663667  0.487992
# 7   0.779199  0.792327  0.225431  ...  0.137218  0.493170  0.527606  0.711286
# 8   0.383116  0.665737  0.828707  ...  0.302363  0.235168  0.396137  0.528184
# 9   0.756652  0.482920  0.354311  ...  0.276840  0.691687  0.245489  0.605039
# 10  0.167420  0.619424  0.422620  ...  0.508608  0.430902  0.366747  0.548850
# 11  0.248172  0.509199  0.392796  ...  0.752728  0.592556  0.774873  0.316793
# 12  0.143785  0.605598  0.353666  ...  0.331253  0.274757  0.424257  0.214938
# 13  0.893111  0.539350  0.771963  ...  0.502076  0.743381  0.491830  0.791108
# 14  0.196283  0.466530  0.028357  ...  0.775315  0.256897  0.688828  0.241821
# 15  0.315374  0.588371  0.382606  ...  0.064465  0.145034  0.166959  0.089913
# 16  0.078537  0.076144  0.171560  ...  0.580373  0.721394  0.319561  0.356257
# 17  0.170414  0.174722  0.143411  ...  0.558898  0.613887  0.706759  0.750189
# 18  0.337048  0.371265  0.388750  ...  0.218437  0.151808  0.242150  0.215529
# 19  0.167872  0.179866  0.370505  ...  0.237743  0.253160  0.247287  0.160709
# 20  0.452181  0.173127  0.000000  ...  0.312510  0.576288  0.511569  0.835649
# 21  0.175083  0.047150  0.187068  ...  0.573986  0.395455  0.444400  0.273478
# 22  0.083941  0.032245  0.060383  ...  0.078437  0.109748  0.031829  0.066886
# 23  0.288519  0.197156  0.174060  ...  0.164678  0.323963  0.219208  0.337940
# 24  0.246676  0.337477  0.325869  ...  0.586157  0.810003  0.986828  0.868365
# 25  0.468999  0.479170  0.333061  ...  0.458255  0.865961  0.711892  1.000000
# 26  0.536393  0.279139  0.527783  ...  0.305948  0.728494  0.562095  0.683428
# 27  0.483394  0.689146  0.611617  ...  0.812696  0.337229  0.734533  0.596222
# 28  0.250775  0.336320  0.058840  ...  0.282429  0.149487  0.308734  0.181698
# 29  0.553094  0.285575  0.435364  ...  0.229214  0.798084  0.518767  0.810668
#
#          V53       V54       V55       V56       V57       V58
# 0   0.307312  0.345395  0.131380  0.187419  0.526534  0.278058
# 1   0.159312  0.055810  0.132622  0.134528  0.145170  0.133288
# 2   0.173245  0.305856  0.060930  0.020953  0.136159  0.136416
# 3   0.145530  0.328067  0.144526  0.000000  0.164740  0.153511
# 4   0.017671  0.127819  0.189742  0.129506  0.222788  0.209515
# 5   0.632952  0.837093  0.680095  0.645609  0.877785  0.940996
# 6   0.521265  0.075873  0.015786  0.395363  0.058947  0.265265
# 7   0.817157  0.694216  0.430474  0.188893  0.727193  0.847229
# 8   0.755947  0.335771  0.430457  0.072411  0.000000  0.211529
# 9   0.757836  0.471750  0.887742  0.784484  0.644099  0.789311
# 10  0.703582  1.000000  0.375085  0.418056  0.411742  0.413291
# 11  0.623565  0.418674  0.535842  0.283514  0.512384  0.439259
# 12  0.549247  0.618120  0.260451  0.256390  0.522878  0.473593
# 13  0.646717  0.539255  0.771116  1.000000  0.770599  0.831621
# 14  0.454115  0.138470  0.343396  0.113204  0.189119  0.271976
# 15  0.096953  0.068680  0.037770  0.130259  0.114046  0.224161
# 16  0.107340  0.165108  0.867384  0.612737  1.000000  0.697907
# 17  0.639429  0.413494  0.627956  0.439140  0.912723  1.000000
# 18  0.479606  1.000000  0.184719  0.229122  0.137242  0.212665
# 19  0.392749  0.864649  0.423193  0.738145  0.341909  0.199137
# 20  0.454748  0.150750  0.285954  0.013298  0.642583  0.409078
# 21  0.265757  0.094002  0.616660  0.721092  0.424803  0.335483
# 22  0.072328  0.045660  0.066511  0.059211  0.119322  0.139399
# 23  0.257765  0.193674  0.128802  0.153447  0.262406  0.332867
# 24  0.907226  0.664465  0.249249  0.000000  0.892964  1.000000
# 25  0.776102  0.369501  0.413888  0.307300  0.807319  0.924231
# 26  0.632228  0.360304  0.661574  0.783469  0.925562  0.912899
# 27  0.604043  0.393322  0.187566  0.298889  0.557392  0.313102
# 28  0.111748  0.048841  0.055725  0.061814  0.164603  0.168241
# 29  0.625588  0.568477  0.834590  0.872232  0.870726  0.948523
#
# [30 rows x 59 columns]

# %%
# cluster_1 = ['blueberry','ocean','sky','beach']
# cluster_2 = ['sunset','mango','watermelon','strawberry']
# cluster_3 = ['day','noon','happy','above']
# cluster_4 = ['fearful','angry','disgust','night']
# cluster_5 = ['far','below','dusk','sad']

# %%
cluster_1 = ['speed','reliability','comfort','safety','efficiency']
cluster_2 = ['apple','cherry','grape','peach','banana']
cluster_3 = ['driving','sleeping','eating','working','leisure']
cluster_4 = ['carrot','celery','corn','eggplant','mushroom']
p_clust = ['blueberry','mango','strawberry','watermelon','lemon']

# %%
#color_dict = pd.read_csv('../data/uw_71_color_dict.csv')
#color_dict = pd.read_csv('../data/colorability_color_dict.csv')
color_dict = pd.read_csv('../data/color_dict.csv')
color_dict=color_dict.drop(columns='Unnamed: 0')
color_dict=color_dict.rename(columns={"index": "ind"})
color_dict
# Out:
#         hex  ind
# 0   #0e8a19   47
# 1   #ac6619   51
# 2   #608218   45
# 3   #96c58c   35
# 4   #443b14   37
# 5   #a0bae6    4
# 6   #cc4f1b   53
# 7   #b9b9b9   26
# 8   #7ec6ba   22
# 9   #3518ad   18
# 10  #a8664b   41
# 11  #1c3d61    2
# 12  #c7b88b   39
# 13  #83764c   38
# 14  #aac510   55
# 15  #67cf5c   48
# 16  #600b84   14
# 17  #b62ef2   20
# 18  #a3c55b   46
# 19  #55824d   34
# 20  #777777   25
# 21  #5e2b3a   28
# 22  #d5a9e4    7
# 23  #897618   49
# 24  #fba714   58
# 25  #73cf10   56
# 26  #e6a8b7   30
# 27  #5e78a1    3
# 28  #2e3086   12
# 29  #632b14   40
# 30  #90689f    6
# 31  #f7a75a   52
# 32  #cd26c7   16
# 33  #e81a4b   44
# 34  #ea1d1d   54
# 35  #4bcf8e   36
# 36  #746bca   13
# 37  #512d5f    5
# 38  #a06776   29
# 39  #ffffff   27
# 40  #72005e    8
# 41  #077acc   11
# 42  #db1f9d   10
# 43  #d0b85a   50
# 44  #3b8378   21
# 45  #000000   23
# 46  #f1a78a   42
# 47  #c34f74   31
# 48  #b8509e    9
# 49  #e31b73   32
# 50  #8558f4   19
# 51  #a553c8   15
# 52  #d5b811   57
# 53  #4dc7e8    1
# 54  #2f6ef6   17
# 55  #184415   33
# 56  #3b3b3b   24
# 57  #c94e4b   43

# %% [markdown]
# ## UW 71

# %%
sns.palplot(color_dict.sort_values(by=['ind']).hex.tolist())

# %% [markdown]
# ## Best Colors

# %%
sns.palplot(color_dict[color_dict.ind.isin( best_color_inds)].hex.tolist())

# %% [markdown]
# ## Worst Colors

# %%
sns.palplot(color_dict[color_dict.ind.isin( worst_color_inds)].hex.tolist())

# %%
color_dict
# Out:
#         hex  ind
# 0   #d0e942   68
# 1   #a0bae6   14
# 2   #83764c   43
# 3   #b62ef2    4
# 4   #000000   25
# ..      ...  ...
# 66  #d5a9e4   17
# 67  #e81a4b   50
# 68  #c7b88b   44
# 69  #c8e97d   56
# 70  #cd26c7   10
#
# [71 rows x 2 columns]

# %%
color_dict[color_dict.ind.isin(soln+1)].hex
# Out:
# 9     #b8509e
# 12    #a553c8
# 21    #1c3d61
# 35    #746bca
# 66    #d5a9e4
# Name: hex, dtype: object

# %%
soln
# Out:
# array([18, 16,  6,  8, 11])

# %%
def display_ai1(cluster, method = 'balanced'):    ###normal assignment inference
    concepts = cluster
    method = method
    title = method
    ds = d[d.concept.isin(concepts)]
    dsa = np.array(ds.loc[:, ds.columns != 'concept'])
    soln = assignment_solve(dsa, method=method) 
    fig=plt.figure(figsize=(16,8))
    rectangle1 = plt.Rectangle((10, 10), 10, 10, fc=color_dict[color_dict.ind==soln[0]+1].hex.values[0])
    rectangle2 = plt.Rectangle((22, 10), 10, 10, fc=color_dict[color_dict.ind==soln[1]+1].hex.values[0])
    rectangle3 = plt.Rectangle((34, 10), 10, 10, fc=color_dict[color_dict.ind==soln[2]+1].hex.values[0])
    rectangle4 = plt.Rectangle((46, 10), 10, 10, fc=color_dict[color_dict.ind==soln[3]+1].hex.values[0])
    rectangle5 = plt.Rectangle((58, 10), 10, 10, fc=color_dict[color_dict.ind==soln[4]+1].hex.values[0])

    assign_dict={}
    for i,this_sol in enumerate(soln):
        assign_dict[ds.concept.iloc[i]]=color_dict[color_dict.ind==soln[i]+1].hex.values[0]
        


    plt.gca().add_patch(rectangle1)
    plt.gca().add_patch(rectangle2)
    plt.gca().add_patch(rectangle3)
    plt.gca().add_patch(rectangle4)
    plt.gca().add_patch(rectangle5)
    plt.gca().axes.get_xaxis().set_ticks([])
    plt.gca().axes.get_yaxis().set_ticks([])
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.text(13, 22, ds.concept.iloc[0], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(26, 22, ds.concept.iloc[1], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(38, 22, ds.concept.iloc[2], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(50, 22, ds.concept.iloc[3], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(62, 22, ds.concept.iloc[4], bbox=dict(facecolor='w', alpha=0.5))

    if title:
        plt.title(title,pad=80)
    ax = fig.add_subplot(1, 1, 1)
    #ax.set_title('Vertically offset title', pad=40)
    ax.set_facecolor((0.8, 0.8, 0.8))
    plt.axis('scaled')
    plt.show()
    print(assign_dict)

# %%
def display_ai2(cluster, method = 'balanced'):    
    concepts = cluster
    method = method
    title = 'max confusability with ' + method


    ds = d[d.concept.isin(concepts)]
    ratings_cols = ds.columns[1:]

    dsa = np.array(ds[ratings_cols])

    soln = assignment_solve(dsa, method=method) 

    ds = ds.drop(ratings_cols[soln],axis=1)

    ratings_cols = ds.columns[1:]

    ratings_arr = np.array(ds[ratings_cols])


    ## compute p_ij
    ratings_arr = ratings_arr/ratings_arr.sum(axis=0)


    ent_arr = np.apply_along_axis(compute_ent, 1, ratings_arr)

    ## compute entropy per color
    H_n = ent_arr.sum(axis=0)

    ## get worst and best colors

    worst_color_inds = (-H_n).argsort()[:5]
    best_color_inds = (H_n).argsort()[:5]

    worst_col_names = ratings_cols[worst_color_inds].tolist()

    ratings_cols_l = ratings_cols.tolist()
    worst_color_inds = np.array([i for i in range(len(ratings_cols_l)) if ratings_cols_l[i] in worst_col_names])
    #sns.palplot(color_dict[color_dict.ind.isin( worst_color_inds + 1)].hex.tolist())


    dsa = np.array(ds[ratings_cols[(worst_color_inds)]])
    
    soln = assignment_solve(dsa, method='balanced') 
    print(soln, ds[ratings_cols[(worst_color_inds)]])
    
    fig=plt.figure(figsize=(16,8))
    rectangle1 = plt.Rectangle((10, 10), 10, 10, fc=color_dict[color_dict.ind==int(worst_col_names[soln[0]].split('V')[1])].hex.values[0])
    rectangle2 = plt.Rectangle((22, 10), 10, 10, fc=color_dict[color_dict.ind==int(worst_col_names[soln[1]].split('V')[1])].hex.values[0])
    rectangle3 = plt.Rectangle((34, 10), 10, 10, fc=color_dict[color_dict.ind==int(worst_col_names[soln[2]].split('V')[1])].hex.values[0])
    rectangle4 = plt.Rectangle((46, 10), 10, 10, fc=color_dict[color_dict.ind==int(worst_col_names[soln[3]].split('V')[1])].hex.values[0])
    rectangle5 = plt.Rectangle((58, 10), 10, 10, fc=color_dict[color_dict.ind==int(worst_col_names[soln[4]].split('V')[1])].hex.values[0])


    plt.gca().add_patch(rectangle1)
    plt.gca().add_patch(rectangle2)
    plt.gca().add_patch(rectangle3)
    plt.gca().add_patch(rectangle4)
    plt.gca().add_patch(rectangle5)
    plt.gca().axes.get_xaxis().set_ticks([])
    plt.gca().axes.get_yaxis().set_ticks([])
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.text(13, 22, ds.concept.iloc[0], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(26, 22, ds.concept.iloc[1], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(38, 22, ds.concept.iloc[2], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(50, 22, ds.concept.iloc[3], bbox=dict(facecolor='w', alpha=0.5))
    plt.text(62, 22, ds.concept.iloc[4], bbox=dict(facecolor='w', alpha=0.5))

    if title:
        plt.title(title,pad=80)
    ax = fig.add_subplot(1, 1, 1)
    #ax.set_title('Vertically offset title', pad=40)
    ax.set_facecolor((0.8, 0.8, 0.8))
    plt.axis('scaled')
    plt.show()

# %%
H_n.shape
# Out:
# (71,)

# %%
display_ai1(p_clust)
# Out:
# {'blueberry': '#2e3086', 'lemon': '#aac510', 'mango': '#f7a75a', 'strawberry': '#db1f9d', 'watermelon': '#184415'}

# %%
display_ai1(cluster_1)
#display_ai2(cluster_1)
# Out:
# {'comfort': '#f1a78a', 'efficiency': '#2f6ef6', 'reliability': '#443b14', 'safety': '#55824d', 'speed': '#e81a4b'}

# %%
display_ai1(cluster_2)
#display_ai2(cluster_2)
# Out:
# {'apple': '#3efe44', 'banana': '#fcdb42', 'cherry': '#e31b73', 'grape': '#512d5f', 'peach': '#f1a78a'}

# %%
display_ai1(cluster_3)
#display_ai2(cluster_3)
# Out:
# {'driving': '#3efe44', 'eating': '#cc4f1b', 'leisure': '#39f6e0', 'sleeping': '#2e3086', 'working': '#83764c'}

# %%
display_ai1(cluster_4)
#display_ai2(cluster_4)
# Out:
# {'carrot': '#cc4f1b', 'celery': '#8cf47e', 'corn': '#fcdb42', 'eggplant': '#600b84', 'mushroom': '#83764c'}

# %%
### OLD DISPLAY FUNC DONT REMOVE


# def display_ai(d = d,concepts=cluster_1, method='isolated', title='', show=True, save_fig=False):
#     plt.rc('font', size=35)   
#     ds = d[d.concept.isin(concepts)]
#     dsa = np.array(ds.loc[:, ds.columns != 'concept'])
#     soln = assignment_solve(dsa, method=method) 
#     fig=plt.figure(figsize=(16,8))
#     rectangle1 = plt.Rectangle((10, 10), 10, 10, fc=color_dict[color_dict.ind==soln[0]+1].hex.values[0])
#     rectangle2 = plt.Rectangle((22, 10), 10, 10, fc=color_dict[color_dict.ind==soln[1]+1].hex.values[0])
#     rectangle3 = plt.Rectangle((34, 10), 10, 10, fc=color_dict[color_dict.ind==soln[2]+1].hex.values[0])
#     rectangle4 = plt.Rectangle((46, 10), 10, 10, fc=color_dict[color_dict.ind==soln[3]+1].hex.values[0])

#     plt.gca().add_patch(rectangle1)
#     plt.gca().add_patch(rectangle2)
#     plt.gca().add_patch(rectangle3)
#     plt.gca().add_patch(rectangle4)
#     plt.gca().axes.get_xaxis().set_ticks([])
#     plt.gca().axes.get_yaxis().set_ticks([])
#     plt.gca().spines['top'].set_visible(False)
#     plt.gca().spines['right'].set_visible(False)
#     plt.gca().spines['bottom'].set_visible(False)
#     plt.gca().spines['left'].set_visible(False)
#     plt.text(13, 22, ds.concept.iloc[0], bbox=dict(facecolor='w', alpha=0.5))
#     plt.text(26, 22, ds.concept.iloc[1], bbox=dict(facecolor='w', alpha=0.5))
#     plt.text(38, 22, ds.concept.iloc[2], bbox=dict(facecolor='w', alpha=0.5))
#     plt.text(50, 22, ds.concept.iloc[3], bbox=dict(facecolor='w', alpha=0.5))

#     if title:
#         plt.title(title, pad=75)
#     ax = fig.add_subplot(1, 1, 1)
#     #ax.set_title('Vertically offset title', pad=40)
#     ax.set_facecolor((0.8, 0.8, 0.8))
#     plt.axis('scaled')
#     if show==True:
#         plt.show()
#     return(ax.get_figure(), soln)
#     if save_fig:
#         plt.savefig('_{}'.format(method), format='pdf')

# %%
cluster_4
# Out:
# ['carrot', 'celery', 'corn', 'eggplant', 'mushroom']

# %%
class Calculator:
    def compute(w, x, y, z=3):
        return(w,x,y,z)
        #return w+y*z

calc = Calculator()
calc.compute(7, 4, 5)
# Out:
# (<__main__.Calculator at 0x11ae95d90>, 7, 4, 5)

# %%
display_ai(d,cluster_2,'isolated')

# %%
display_ai(d,cluster_2,'balanced')

# %%
display_ai(d,cluster_3,'isolated')

# %%
display_ai(d,cluster_3,'balanced')

# %%
display_ai(d,cluster_4,'isolated')

# %%
display_ai(d,cluster_4,'balanced')

# %%
bad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-d1c7bfdc85d1> in <module>
# ----> 1 bad_col_inds
#
# NameError: name 'bad_col_inds' is not defined

# %%
display_ai(d,cluster_5,'isolated')

# %% [markdown]
# ### Reconstructing with <30 PCs

# %% [markdown]
# Try with one cluster

# %%
#../data/
rmat = pd.read_csv('ratings_matrix_11PC.csv')
rmat =rmat.drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})

# %%
display_ai(d = rmat, concepts=cluster_2, method='balanced')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 150em; }</style>"))


for i in range(2,12):
    rmat = pd.read_csv('ratings_matrix_{}PC.csv'.format(i)).drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})
    
    display_ai(d = rmat, concepts=cluster_2, method='balanced',title='Number of Components: {}'.format(i))

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 150em; }</style>"))


for i in range(2,12):
    rmat = rmat = pd.read_csv('ratings_matrix_{}PC.csv'.format(i)).drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})
    
    display_ai(d = rmat, concepts=cluster_1, method='isolated',title='Number of Components:{}'.format(i))

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 150em; }</style>"))


for i in range(2,31):
    rmat = pd.read_csv('ratings_matrix_{}PC.csv'.format(i))
    rmat = rmat.drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})
    
    display_ai(d = rmat, concepts=cluster_2, method='balanced',title='Number of Components:{}'.format(i))

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 150em; }</style>"))


for i in range(2,31):
    rmat = pd.read_csv('ratings_matrix_{}PC.csv'.format(i))
    rmat = rmat.drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})
    fig,soln = display_ai(d = rmat, concepts=cluster_4, method='balanced',title='Number of Components:{}'.format(i))
    print(soln)
    fig.savefig('{}_{}PC.pdf'.format('cluster4',i), format = 'pdf',bbox_inches=None, pad_inches=0, transparent=True)

# %%
8*3*16

# %%
rmat29 = pd.read_csv('ratings_matrix_{}PC.csv'.format(29)).drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})

# %%
rmat29

# %%
rmat29 = pd.read_csv('ratings_matrix_{}PC.csv'.format(29))
rmat29 = rmat29.drop(rmat29.columns[['Unnamed: 0']], axis=1)

# %%
_29mat = pd.read_csv('ratings_matrix_{}PC.csv'.format(29))
_30mat = pd.read_csv('ratings_matrix_{}PC.csv'.format(30))

# %%
_29mat=_29mat.drop(pmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})
_30mat = _30mat.drop(pmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})

# %%
_29arr= np.array(_29mat[_29mat.concept == 'sunset'].loc[:,_29mat.columns!='concept'])

# %%
_30arr=np.array(_30mat[_30mat.concept == 'sunset'].loc[:,_30mat.columns!= 'concept'])

# %%
diff= _30arr - _29arr

# %%
np.linalg.norm(diff, 2)

# %% [markdown]
# ### Clusters (within):
#
# 1. Blueberry, Ocean, Beach, Sky
# 2. Dawn, Day, Happy, Noon
# 3. Angry, Below, Disgust, Far
# 4. Field, Lemon, Strawberry, Watermelon

# %% [markdown]
# ### Clusters (between):
#
# 1. Blueberry, Noon, Lemon, Far
# 2. Beach, Dawn, Strawberry, Angry
# 3. Ocean, Happy, Watermelon, Disgust
# 4. Sky, Day, Field, Below

# %%
wcluster1 = ['blueberry', 'ocean', 'beach', 'sky']
wcluster2 = ['dawn', 'day','happy','noon']
wcluster3 = ['angry','below','disgust','far']
wcluster4 = ['field', 'lemon', 'strawberry', 'watermelon']

bcluster1 = ['blueberry', 'noon', 'lemon', 'far']
bcluster2 = ['beach', 'dawn', 'strawberry', 'angry']
bcluster3 = ['ocean', 'happy', 'watermelon', 'disgust']
bcluster4 = ['sky', 'day', 'field', 'below']

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 150em; }</style>"))

solns=[]
for i in range(2,31):
    rmat = pd.read_csv('ratings_matrix_{}PC.csv'.format(i))
    rmat = rmat.drop(rmat.columns[[1]], axis=1).rename(columns={'Unnamed: 0':'concept'})
    fig,soln = display_ai(d = rmat, show=False, concepts=wcluster4, method='balanced',title='Number of Components:{}'.format(i))
    solns.append(soln)

# %%
len(np.unique(solns, axis=0))

# %% [markdown]
# # Palette counts
#
# #### Between cluster
#
# * cluster 1: 9
# * cluster 2: 11
# * cluster 3: 10
# * cluster 4: 7
#
# #### Within cluster
#
# * cluster 1: 11
# * cluster 2: 16
# * cluster 3: 15
# * cluster 4: 18

# %%
solns

# %%
b = pd.read_json('../data/test_cbai.json')

# %%
c = b[b.trial_type=='assignment-inference']

# %%
c = c.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-4e22f17dae26> in <module>
# ----> 1 c = c.reset_index()
#       2 c.columns
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4853                 # to ndarray and maybe infer different dtype
#    4854                 level_values = _maybe_casted_values(lev, lab)
# -> 4855                 new_obj.insert(0, name, level_values)
#    4856
#    4857         new_obj.index = new_index
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
rt=[]
trial_index=[]
label_option=[]
bar_col=[]
answer=[]
response=[]
condition=[]
repetition=[]
category=[]
pal_source=[]
accuracy=[]
total_accuracy=[]
order_num=[]
x=0



for index,row in c.iterrows():
    
    for i in range(5):
        rt.append(row.rt)
        trial_index.append(index)
        label_option.append( eval(row.label_options))
        bar_col.append(eval(row.bar_cols)[i])
        answer.append(eval(row.answer_key)[i])
        response.append( eval(row.label_responses)[i])
        condition.append(row.condition)
        repetition.append(row.repetition)
        category.append(row.category)
        pal_source.append( row.pal_source)
        accuracy.append( eval(row.accuracies)[i])
        total_accuracy.append( row['total_accuracy'])
        order_num.append(row.order_num)

# %%
(pd.DataFrame({'trial_index':trial_index,'condition':condition,'pal_source':pal_source,'order_num':order_num,\
               'category':category,'repetition':repetition,'label_option':label_option,'answer':answer,\
               'bar_col':bar_col,'response':response,\
             'accuracy':accuracy,'total_accuracy':total_accuracy,'rt':rt})).to_csv('../cbai_ex.csv')

# %%
row
# Out:
# level_0                                                            40
# index                                                              49
# rt                                                               7415
# responses                                                         NaN
# question_order                                                    NaN
# trial_type                                       assignment-inference
# trial_index                                                        49
# time_elapsed                                                   567002
# internal_node_id                                             0.0-49.0
# stimulus                                                          NaN
# button_pressed                                                    NaN
# key_press                                                         NaN
# label_options        ["eggplant","celery","corn","mushroom","carrot"]
# bar_cols            ["#83764c","#cc4f1b","#8cf47e","#fcdb42","#600...
# answer_key           ["mushroom","carrot","celery","corn","eggplant"]
# label_responses      ["celery","corn","carrot","mushroom","eggplant"]
# condition                                                 "colorable"
# repetition                                                          4
# category                                                 "vegetables"
# pal_source                                                    "uw_71"
# accuracies                                                [0,0,0,0,1]
# total accuracy                                                      1
# order_num                                                           4
# Name: 40, dtype: object

# %%
c
# Out:
#     level_0  index       rt responses question_order            trial_type  \
# 0         0      5  91935.0       NaN            NaN  assignment-inference
# 1         1      6   9508.0       NaN            NaN  assignment-inference
# 2         2      7   9590.0       NaN            NaN  assignment-inference
# 3         3      8   7144.0       NaN            NaN  assignment-inference
# 4         4      9   8467.0       NaN            NaN  assignment-inference
# 5         5     10   7601.0       NaN            NaN  assignment-inference
# 6         6     11   7663.0       NaN            NaN  assignment-inference
# 7         7     12   8463.0       NaN            NaN  assignment-inference
# 8         8     13   8387.0       NaN            NaN  assignment-inference
# 9         9     15  43565.0       NaN            NaN  assignment-inference
# 10       10     16   8623.0       NaN            NaN  assignment-inference
# 11       11     17   9935.0       NaN            NaN  assignment-inference
# 12       12     18   8366.0       NaN            NaN  assignment-inference
# 13       13     19   8429.0       NaN            NaN  assignment-inference
# 14       14     20   7380.0       NaN            NaN  assignment-inference
# 15       15     21  27027.0       NaN            NaN  assignment-inference
# 16       16     22  17854.0       NaN            NaN  assignment-inference
# 17       17     24   7405.0       NaN            NaN  assignment-inference
# 18       18     25   6915.0       NaN            NaN  assignment-inference
# 19       19     26   6999.0       NaN            NaN  assignment-inference
# 20       20     27   8871.0       NaN            NaN  assignment-inference
# 21       21     28   6912.0       NaN            NaN  assignment-inference
# 22       22     29   6416.0       NaN            NaN  assignment-inference
# 23       23     30   8634.0       NaN            NaN  assignment-inference
# 24       24     31   7540.0       NaN            NaN  assignment-inference
# 25       25     33   7016.0       NaN            NaN  assignment-inference
# 26       26     34   7032.0       NaN            NaN  assignment-inference
# 27       27     35   8055.0       NaN            NaN  assignment-inference
# 28       28     36   8468.0       NaN            NaN  assignment-inference
# 29       29     37   8943.0       NaN            NaN  assignment-inference
# 30       30     38   6656.0       NaN            NaN  assignment-inference
# 31       31     39   7088.0       NaN            NaN  assignment-inference
# 32       32     40   8131.0       NaN            NaN  assignment-inference
# 33       33     42   6871.0       NaN            NaN  assignment-inference
# 34       34     43   6488.0       NaN            NaN  assignment-inference
# 35       35     44   8590.0       NaN            NaN  assignment-inference
# 36       36     45  72449.0       NaN            NaN  assignment-inference
# 37       37     46   9086.0       NaN            NaN  assignment-inference
# 38       38     47   6464.0       NaN            NaN  assignment-inference
# 39       39     48   6293.0       NaN            NaN  assignment-inference
# 40       40     49   7415.0       NaN            NaN  assignment-inference
#
#     trial_index  time_elapsed internal_node_id stimulus  ...  \
# 0             5        102559          0.0-5.0      NaN  ...
# 1             6        112070          0.0-6.0      NaN  ...
# 2             7        121663          0.0-7.0      NaN  ...
# 3             8        128810          0.0-8.0      NaN  ...
# 4             9        137280          0.0-9.0      NaN  ...
# 5            10        144883         0.0-10.0      NaN  ...
# 6            11        152549         0.0-11.0      NaN  ...
# 7            12        161015         0.0-12.0      NaN  ...
# 8            13        169405         0.0-13.0      NaN  ...
# 9            15        231383         0.0-15.0      NaN  ...
# 10           16        240009         0.0-16.0      NaN  ...
# 11           17        249948         0.0-17.0      NaN  ...
# 12           18        258315         0.0-18.0      NaN  ...
# 13           19        266746         0.0-19.0      NaN  ...
# 14           20        274128         0.0-20.0      NaN  ...
# 15           21        301158         0.0-21.0      NaN  ...
# 16           22        319014         0.0-22.0      NaN  ...
# 17           24        327680         0.0-24.0      NaN  ...
# 18           25        334598         0.0-25.0      NaN  ...
# 19           26        341600         0.0-26.0      NaN  ...
# 20           27        350474         0.0-27.0      NaN  ...
# 21           28        357389         0.0-28.0      NaN  ...
# 22           29        363808         0.0-29.0      NaN  ...
# 23           30        372445         0.0-30.0      NaN  ...
# 24           31        379987         0.0-31.0      NaN  ...
# 25           33        387966         0.0-33.0      NaN  ...
# 26           34        395000         0.0-34.0      NaN  ...
# 27           35        403058         0.0-35.0      NaN  ...
# 28           36        411529         0.0-36.0      NaN  ...
# 29           37        420475         0.0-37.0      NaN  ...
# 30           38        427133         0.0-38.0      NaN  ...
# 31           39        434224         0.0-39.0      NaN  ...
# 32           40        442358         0.0-40.0      NaN  ...
# 33           42        450200         0.0-42.0      NaN  ...
# 34           43        456691         0.0-43.0      NaN  ...
# 35           44        465284         0.0-44.0      NaN  ...
# 36           45        537735         0.0-45.0      NaN  ...
# 37           46        546824         0.0-46.0      NaN  ...
# 38           47        553289         0.0-47.0      NaN  ...
# 39           48        559585         0.0-48.0      NaN  ...
# 40           49        567002         0.0-49.0      NaN  ...
#
#                                              bar_cols  \
# 0   ["#2e3086","#aac510","#f7a75a","#db1f9d","#184...
# 1   ["#f1a78a","#2f6ef6","#443b14","#55824d","#e81...
# 2   ["#cc4f1b","#8cf47e","#fcdb42","#600b84","#837...
# 3   ["#17becf","#bcbd22","#d62728","#9467bd","#c49...
# 4   ["#d62728","#ff7f0e","#f7b6d2","#1f77b4","#8c5...
# 5   ["#ff7f0e","#98df8a","#bcbd22","#9467bd","#c7c...
# 6   ["#3efe44","#fcdb42","#e31b73","#512d5f","#f1a...
# 7   ["#3efe44","#cc4f1b","#39f6e0","#2e3086","#837...
# 8   ["#f7b6d2","#ff7f0e","#9467bd","#bcbd22","#d62...
# 9   ["#f7b6d2","#1f77b4","#8c564b","#d62728","#ff7...
# 10  ["#39f6e0","#2e3086","#83764c","#3efe44","#cc4...
# 11  ["#fcdb42","#600b84","#83764c","#cc4f1b","#8cf...
# 12  ["#e31b73","#512d5f","#f1a78a","#3efe44","#fcd...
# 13  ["#bcbd22","#9467bd","#c7c7c7","#ff7f0e","#98d...
# 14  ["#9467bd","#bcbd22","#d62728","#f7b6d2","#ff7...
# 15  ["#d62728","#9467bd","#c49c94","#17becf","#bcb...
# 16  ["#443b14","#55824d","#e81a4b","#f1a78a","#2f6...
# 17  ["#1f77b4","#8c564b","#d62728","#ff7f0e","#f7b...
# 18  ["#55824d","#e81a4b","#f1a78a","#2f6ef6","#443...
# 19  ["#9467bd","#c49c94","#17becf","#bcbd22","#d62...
# 20  ["#600b84","#83764c","#cc4f1b","#8cf47e","#fcd...
# 21  ["#9467bd","#c7c7c7","#ff7f0e","#98df8a","#bcb...
# 22  ["#2e3086","#83764c","#3efe44","#cc4f1b","#39f...
# 23  ["#bcbd22","#d62728","#f7b6d2","#ff7f0e","#946...
# 24  ["#512d5f","#f1a78a","#3efe44","#fcdb42","#e31...
# 25  ["#ff7f0e","#f7b6d2","#1f77b4","#8c564b","#d62...
# 26  ["#cc4f1b","#39f6e0","#2e3086","#83764c","#3ef...
# 27  ["#ff7f0e","#9467bd","#bcbd22","#d62728","#f7b...
# 28  ["#bcbd22","#d62728","#9467bd","#c49c94","#17b...
# 29  ["#8cf47e","#fcdb42","#600b84","#83764c","#cc4...
# 30  ["#2f6ef6","#443b14","#55824d","#e81a4b","#f1a...
# 31  ["#fcdb42","#e31b73","#512d5f","#f1a78a","#3ef...
# 32  ["#98df8a","#bcbd22","#9467bd","#c7c7c7","#ff7...
# 33  ["#8c564b","#d62728","#ff7f0e","#f7b6d2","#1f7...
# 34  ["#83764c","#3efe44","#cc4f1b","#39f6e0","#2e3...
# 35  ["#e81a4b","#f1a78a","#2f6ef6","#443b14","#558...
# 36  ["#c7c7c7","#ff7f0e","#98df8a","#bcbd22","#946...
# 37  ["#d62728","#f7b6d2","#ff7f0e","#9467bd","#bcb...
# 38  ["#f1a78a","#3efe44","#fcdb42","#e31b73","#512...
# 39  ["#c49c94","#17becf","#bcbd22","#d62728","#946...
# 40  ["#83764c","#cc4f1b","#8cf47e","#fcdb42","#600...
#
#                                            answer_key  \
# 0   ["blueberry","lemon","mango","strawberry","wat...
# 1   ["comfort","efficiency","reliability","safety"...
# 2    ["carrot","celery","corn","eggplant","mushroom"]
# 3         ["apple","banana","cherry","grape","peach"]
# 4   ["driving","eating","leisure","sleeping","work...
# 5    ["carrot","celery","corn","eggplant","mushroom"]
# 6         ["apple","banana","cherry","grape","peach"]
# 7   ["driving","eating","leisure","sleeping","work...
# 8   ["comfort","efficiency","reliability","safety"...
# 9   ["leisure","sleeping","working","driving","eat...
# 10  ["leisure","sleeping","working","driving","eat...
# 11   ["corn","eggplant","mushroom","carrot","celery"]
# 12        ["cherry","grape","peach","apple","banana"]
# 13   ["corn","eggplant","mushroom","carrot","celery"]
# 14  ["reliability","safety","speed","comfort","eff...
# 15        ["cherry","grape","peach","apple","banana"]
# 16  ["reliability","safety","speed","comfort","eff...
# 17  ["sleeping","working","driving","eating","leis...
# 18  ["safety","speed","comfort","efficiency","reli...
# 19        ["grape","peach","apple","banana","cherry"]
# 20   ["eggplant","mushroom","carrot","celery","corn"]
# 21   ["eggplant","mushroom","carrot","celery","corn"]
# 22  ["sleeping","working","driving","eating","leis...
# 23  ["safety","speed","comfort","efficiency","reli...
# 24        ["grape","peach","apple","banana","cherry"]
# 25  ["eating","leisure","sleeping","working","driv...
# 26  ["eating","leisure","sleeping","working","driv...
# 27  ["efficiency","reliability","safety","speed","...
# 28        ["banana","cherry","grape","peach","apple"]
# 29   ["celery","corn","eggplant","mushroom","carrot"]
# 30  ["efficiency","reliability","safety","speed","...
# 31        ["banana","cherry","grape","peach","apple"]
# 32   ["celery","corn","eggplant","mushroom","carrot"]
# 33  ["working","driving","eating","leisure","sleep...
# 34  ["working","driving","eating","leisure","sleep...
# 35  ["speed","comfort","efficiency","reliability",...
# 36   ["mushroom","carrot","celery","corn","eggplant"]
# 37  ["speed","comfort","efficiency","reliability",...
# 38        ["peach","apple","banana","cherry","grape"]
# 39        ["peach","apple","banana","cherry","grape"]
# 40   ["mushroom","carrot","celery","corn","eggplant"]
#
#                                       label_responses        condition  \
# 0   ["watermelon","lemon","mango","strawberry","bl...             null
# 1   ["reliability","comfort","speed","safety","eff...  "non-colorable"
# 2    ["mushroom","eggplant","celery","carrot","corn"]      "colorable"
# 3         ["apple","banana","peach","grape","cherry"]      "colorable"
# 4   ["eating","sleeping","working","leisure","driv...  "non-colorable"
# 5    ["eggplant","mushroom","corn","carrot","celery"]      "colorable"
# 6         ["cherry","peach","grape","banana","apple"]      "colorable"
# 7   ["leisure","driving","eating","sleeping","work...  "non-colorable"
# 8   ["safety","reliability","efficiency","comfort"...  "non-colorable"
# 9   ["leisure","driving","eating","sleeping","work...  "non-colorable"
# 10  ["eating","driving","sleeping","leisure","work...  "non-colorable"
# 11   ["corn","eggplant","mushroom","carrot","celery"]      "colorable"
# 12        ["apple","grape","peach","cherry","banana"]      "colorable"
# 13   ["celery","carrot","mushroom","eggplant","corn"]      "colorable"
# 14  ["speed","efficiency","comfort","safety","reli...  "non-colorable"
# 15        ["apple","grape","cherry","banana","peach"]      "colorable"
# 16  ["comfort","speed","safety","efficiency","reli...  "non-colorable"
# 17  ["sleeping","eating","leisure","working","driv...  "non-colorable"
# 18  ["safety","efficiency","reliability","comfort"...  "non-colorable"
# 19        ["apple","banana","cherry","grape","peach"]      "colorable"
# 20   ["corn","carrot","celery","eggplant","mushroom"]      "colorable"
# 21   ["celery","corn","mushroom","eggplant","carrot"]      "colorable"
# 22  ["eating","sleeping","driving","working","leis...  "non-colorable"
# 23  ["reliability","efficiency","safety","speed","...  "non-colorable"
# 24        ["banana","grape","peach","apple","cherry"]      "colorable"
# 25  ["eating","driving","sleeping","working","leis...  "non-colorable"
# 26  ["eating","sleeping","driving","leisure","work...  "non-colorable"
# 27  ["comfort","speed","efficiency","reliability",...  "non-colorable"
# 28        ["banana","cherry","grape","peach","apple"]      "colorable"
# 29   ["eggplant","corn","celery","mushroom","carrot"]      "colorable"
# 30  ["comfort","reliability","safety","speed","eff...  "non-colorable"
# 31        ["cherry","apple","banana","peach","grape"]      "colorable"
# 32   ["celery","eggplant","mushroom","carrot","corn"]      "colorable"
# 33  ["driving","working","sleeping","leisure","eat...  "non-colorable"
# 34  ["working","driving","sleeping","leisure","eat...  "non-colorable"
# 35  ["speed","comfort","safety","efficiency","reli...  "non-colorable"
# 36   ["celery","corn","eggplant","carrot","mushroom"]      "colorable"
# 37  ["comfort","reliability","safety","speed","eff...  "non-colorable"
# 38        ["peach","cherry","grape","banana","apple"]      "colorable"
# 39        ["cherry","apple","peach","grape","banana"]      "colorable"
# 40   ["celery","corn","carrot","mushroom","eggplant"]      "colorable"
#
#    repetition      category pal_source   accuracies total accuracy order_num
# 0        null          null       null  [0,1,1,1,0]            3.0      null
# 1           0    "features"    "uw_71"  [0,0,0,1,0]            1.0         0
# 2           0  "vegetables"    "uw_71"  [0,0,0,0,0]            0.0         0
# 3           0      "fruits"   "tab_20"  [1,1,0,1,0]            3.0         0
# 4           0  "activities"   "tab_20"  [0,0,0,0,0]            0.0         0
# 5           0  "vegetables"   "tab_20"  [0,0,1,0,0]            1.0         0
# 6           0      "fruits"    "uw_71"  [0,0,0,0,0]            0.0         0
# 7           0  "activities"    "uw_71"  [0,0,0,1,1]            2.0         0
# 8           0    "features"   "tab_20"  [0,0,0,0,1]            1.0         0
# 9           1  "activities"   "tab_20"  [1,0,0,0,0]            1.0         2
# 10          1  "activities"    "uw_71"  [0,0,0,0,0]            0.0         2
# 11          1  "vegetables"    "uw_71"  [1,1,1,1,1]            5.0         2
# 12          1      "fruits"    "uw_71"  [0,1,1,0,1]            3.0         2
# 13          1  "vegetables"   "tab_20"  [0,0,1,0,0]            1.0         2
# 14          1    "features"   "tab_20"  [0,0,0,0,0]            0.0         2
# 15          1      "fruits"   "tab_20"  [0,1,0,0,0]            1.0         2
# 16          1    "features"    "uw_71"  [0,0,0,0,0]            0.0         2
# 17          2  "activities"   "tab_20"  [1,0,0,0,0]            1.0         3
# 18          2    "features"    "uw_71"  [1,0,0,0,0]            1.0         3
# 19          2      "fruits"   "tab_20"  [0,0,0,0,0]            0.0         3
# 20          2  "vegetables"    "uw_71"  [0,0,0,0,0]            0.0         3
# 21          2  "vegetables"   "tab_20"  [0,0,0,0,0]            0.0         3
# 22          2  "activities"    "uw_71"  [0,0,1,0,1]            2.0         3
# 23          2    "features"   "tab_20"  [0,0,0,0,0]            0.0         3
# 24          2      "fruits"    "uw_71"  [0,0,0,0,1]            1.0         3
# 25          3  "activities"   "tab_20"  [1,0,1,1,0]            3.0         1
# 26          3  "activities"    "uw_71"  [1,0,0,0,0]            1.0         1
# 27          3    "features"   "tab_20"  [0,0,0,0,0]            0.0         1
# 28          3      "fruits"   "tab_20"  [1,1,1,1,1]            5.0         1
# 29          3  "vegetables"    "uw_71"  [0,1,0,1,1]            3.0         1
# 30          3    "features"    "uw_71"  [0,1,1,1,0]            3.0         1
# 31          3      "fruits"    "uw_71"  [0,0,0,1,0]            1.0         1
# 32          3  "vegetables"   "tab_20"  [1,0,0,0,0]            1.0         1
# 33          4  "activities"   "tab_20"  [0,0,0,1,0]            1.0         4
# 34          4  "activities"    "uw_71"  [1,1,0,1,0]            3.0         4
# 35          4    "features"    "uw_71"  [1,1,0,0,0]            2.0         4
# 36          4  "vegetables"   "tab_20"  [0,0,0,0,0]            0.0         4
# 37          4    "features"   "tab_20"  [0,0,0,0,0]            0.0         4
# 38          4      "fruits"    "uw_71"  [1,0,0,0,0]            1.0         4
# 39          4      "fruits"   "tab_20"  [0,1,0,0,0]            1.0         4
# 40          4  "vegetables"    "uw_71"  [0,0,0,0,1]            1.0         4
#
# [41 rows x 23 columns]

# %%
pd.read_json('../data/test_cbai.json').condition
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                null
# 6     "non-colorable"
# 7         "colorable"
# 8         "colorable"
# 9     "non-colorable"
# 10        "colorable"
# 11        "colorable"
# 12    "non-colorable"
# 13    "non-colorable"
# 14                NaN
# 15    "non-colorable"
# 16    "non-colorable"
# 17        "colorable"
# 18        "colorable"
# 19        "colorable"
# 20    "non-colorable"
# 21        "colorable"
# 22    "non-colorable"
# 23                NaN
# 24    "non-colorable"
# 25    "non-colorable"
# 26        "colorable"
# 27        "colorable"
# 28        "colorable"
# 29    "non-colorable"
# 30    "non-colorable"
# 31        "colorable"
# 32                NaN
# 33    "non-colorable"
# 34    "non-colorable"
# 35    "non-colorable"
# 36        "colorable"
# 37        "colorable"
# 38    "non-colorable"
# 39        "colorable"
# 40        "colorable"
# 41                NaN
# 42    "non-colorable"
# 43    "non-colorable"
# 44    "non-colorable"
# 45        "colorable"
# 46    "non-colorable"
# 47        "colorable"
# 48        "colorable"
# 49        "colorable"
# 50                NaN
# 51                NaN
# Name: condition, dtype: object
